# %% [markdown]
# # Data Exploration: Spreadsheet からデータを持ってくる
#
#
# ![Alt text](https://raw.githubusercontent.com/yohman/23-1-Reitaku-GIS/main/Weeks/Week06/images/csv%20to%20map.png)
#
#
# 先週の課題では一つの地図に複数のマーカーを作りましたね。作る過程で、おそらくマーカーを一つ一つコーディングをしたのではないでしょうか。
#
#
# ```python
# # from Chikashi's homework
# kaede = [35.83304899572845, 139.9550263688704]
# asunaro = [35.83218389343381, 139.9559046419524]
# hiiragi = [35.83432746243043, 139.95492044150396]
# library = [35.83288620720931, 139.9560383893833]
# parking = [35.83477548217266, 139.9561361979999]
# bukastu = [35.83480867733186, 139.95489801198133]
# ```
#
# でも、もし100個のマーカーを地図に載せるように言われたらどうする？大変だね！コーディングでやると要領が悪いので、データをspreadsheetで作って、Pythonでインポートしましょう。

# %% [markdown]
# ## CSV ファイルのインポート
#
# では、`mydata.csv`　ファイルをインポートしましょう。クラスのサイトからダウンロードして、このファイルと同じフォルダに保存。
#
# 確認！
# - `mydata.csv` ファイルがこのノートブックファイルと同じルーツであることを再確認

# %% [markdown]
# ### Library import
#
# モジュールを三つ使います：
# - pandas: to import and work with dataframes
# - folium: to create interactive maps
# - matplotlib: to create charts

# %%
# library import
import pandas as pd
import folium
import matplotlib.pyplot as plt

# %% [markdown]
# このようにデータを取り込みます。ちなみに `df` は 【dataframe】の略：

# %%
# import the csv file
df = pd.read_csv('mydata.csv')

# %%
df
# Out:
#           name                                        description   latitude  \
# 0      校舎「かえで」  校舎名の「かえで」には「楓の果実が2つの種子が密着した姿で、それぞれから翼が伸びる翼果である...  35.833049
# 1     校舎「あすなろ」  麗澤大学開学50周年記念事業の一環として2011年4月"森と共生するキャンパス"をコンセプト...  35.832201
# 2          図書館  AVホール・CALL教室を持ち、授業開講時は8:50から19:00（閉講期間中は9:00から...  35.832862
# 3   学生会館「ひいらぎ」  2022年9月にリニューアルオープン。木目とグリーンを基調としたアットホームな雰囲気で、窓か...  35.834304
# 4  麗澤大学生涯教育プラザ  2006年（平成18年）2月竣工。大学院、研究センター、情報システム部、麗澤オープンカレッジ...  35.831934
# 5      校舎「さつき」  <img src="https://www.reitaku-u.ac.jp/news/ima...  35.834119
#
#     longitude      color
# 0  139.955026      green
# 1  139.955906      green
# 2  139.955925      green
# 3  139.954985  cadetblue
# 4  139.956880      green
# 5  139.956113    darkred

# %% [markdown]
# ## Working with dataframes
#
# おめでとう！データの取り込みに成功。それでは基本的なデータを explore するコマンドをいくつか紹介。

# %%
# size of the data (rows, columns)
df.shape
# Out:
# (6, 5)

# %%
# information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         6 non-null      object
#  1   description  6 non-null      object
#  2   latitude     6 non-null      float64
#  3   longitude    6 non-null      float64
#  4   color        6 non-null      object
# dtypes: float64(2), object(3)
# memory usage: 368.0+ bytes

# %% [markdown]
# ↑ここで確認するのは `latitude` and `longitude` が `float` であること。もし `object` であればデータを作り直す必要がある。
#
# 次に、いろんなコマンドでデータをexploreする。一つ一つ、理解しながらじっくり実行するよう。

# %%
# list of columns
df.columns.to_list()
# Out:
# ['name', 'description', 'latitude', 'longitude', 'color']

# %%
# show only specific columns
df[['name','latitude','longitude']]
# Out:
#           name   latitude   longitude
# 0      校舎「かえで」  35.833049  139.955026
# 1     校舎「あすなろ」  35.832201  139.955906
# 2          図書館  35.832862  139.955925
# 3   学生会館「ひいらぎ」  35.834304  139.954985
# 4  麗澤大学生涯教育プラザ  35.831934  139.956880
# 5      校舎「さつき」  35.834119  139.956113

# %%
# get values for a single column
df['longitude']
# Out:
# 0    139.955026
# 1    139.955906
# 2    139.955925
# 3    139.954985
# 4    139.956880
# 5    139.956113
# Name: longitude, dtype: float64

# %%
# put those values in a list
df['latitude'].to_list()
# Out:
# [35.833049, 35.83220147, 35.83286248, 35.83430366, 35.83193431, 35.83411942]

# %% [markdown]
# ### Charts
#
# `matplotlib` を使ってグラフを作成。これも一つ一つ、どのようなコマンドでチャートができるのかを把握するように。

# %%
# line chart
df['latitude'].plot()
# Out:
# <AxesSubplot: >

# %%
# boxplot 箱ヒゲ図
df['latitude'].plot.box(color='red')
# Out:
# <AxesSubplot: >

# %%
# bar graph
df['latitude'].plot.bar(color='green')
# Out:
# <AxesSubplot: >

# %%
# scatterplot 散布図
# ここの 'c' は df の変数の 'color' を指定
# size(s) を変えてみよう
df.plot.scatter(x='longitude',y='latitude',c='color',s=50)
# Out:
# <AxesSubplot: xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# ### Statistics
#
# Pythonは簡単な統計もできます。

# %%
# summary stats
df['latitude'].describe()
# Out:
# count     6.000000
# mean     35.833078
# std       0.000971
# min      35.831934
# 25%      35.832367
# 50%      35.832956
# 75%      35.833852
# max      35.834304
# Name: latitude, dtype: float64

# %%
# summary stats
df['longitude'].describe()
# Out:
# count      6.000000
# mean     139.955806
# std        0.000715
# min      139.954985
# 25%      139.955246
# 50%      139.955916
# 75%      139.956066
# max      139.956880
# Name: longitude, dtype: float64

# %%
# mean 平均値
df['latitude'].mean()
# Out:
# 35.833078390000004

# %%
# median 中央値
df['latitude'].median()
# Out:
# 35.83295574

# %% [markdown]
# では統計を使って、`latitude` and `longitude` の平均値を変数に入れましょう。
#
# さて、この平均値は何を意味するのでしょうか？

# %%
# get center lat/lon
center_lat = df['latitude'].mean()
center_lon = df['longitude'].mean()

print(center_lat,center_lon)
# Out:
# 35.833078390000004 139.95580603333335

# %% [markdown]
# ## Let's loop!
#
# プログラミングの基礎の一つである　`for loop`　があります。「ループ」の言葉通り、何かを【繰り返す】という意味である。

# %%
# my students
students = ['Fumiaki','Yuya','Mifuyu','Pingxin']

# print their names
for name in students:
    print('My name is', name)
# Out:
# My name is Fumiaki
# My name is Yuya
# My name is Mifuyu
# My name is Pingxin

# %% [markdown]
# さて、この「ループ」の概念を使ってデータ `df` の１行ずつアウトプットするには `iterrows()` メソッドを使う。例えば、データの `name` を全部アウトプットするには：

# %%
# loop through your data
for index, row in df.iterrows():
    print(row['name'],row['latitude'])
# Out:
# 校舎「かえで」 35.833049
# 校舎「あすなろ」 35.83220147
# 図書館 35.83286248
# 学生会館「ひいらぎ」 35.83430366
# 麗澤大学生涯教育プラザ 35.83193431
# 校舎「さつき」 35.83411942

# %% [markdown]
# このように、`row` の変数は【各行】を意味するので、`for loop` に入っているときは変数名と共に各行の値をアウトプットすることができる。複数の変数をアウトプットも可能：

# %%
# loop and output multiple column values
for index, row in df.iterrows():
    print(row['name'],row['latitude'],row['longitude'])
# Out:
# 校舎「かえで」 35.833049 139.9550264
# 校舎「あすなろ」 35.83220147 139.9559064
# 図書館 35.83286248 139.9559251
# 学生会館「ひいらぎ」 35.83430366 139.9549849
# 麗澤大学生涯教育プラザ 35.83193431 139.9568801
# 校舎「さつき」 35.83411942 139.9561133

# %% [markdown]
# ### Use the loop in a map
#
# それでは、`for loop` を使って、`df` のポイントを一気にマッピングしよう。

# %%
# make the map
m = folium.Map(location=[center_lat,center_lon], zoom_start=17)

# df をループしてマーカーを作る
for index, row in df.iterrows():
    latlon = [row['latitude'],row['longitude']]
    folium.Marker(latlon, 
                  popup='<div style="width:250px">'+row['description']+'</div>', 
                  tooltip=row['name'],
                  icon=folium.Icon(color=row['color']
                )).add_to(m)

# show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3449f67134763ba5a9bbbc3662f741fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3449f67134763ba5a9bbbc3662f741fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3449f67134763ba5a9bbbc3662f741fb = L.map(
#                 &quot;map_3449f67134763ba5a9bbbc3662f741fb&quot;,
#                 {
#                     center: [35.833078390000004, 139.95580603333335],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f85bfebe042ee0fd3bc264226bbdef8d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3449f67134763ba5a9bbbc3662f741fb);
#
#
#             var marker_ce0f3248ac6a3041f03b5fa897362d35 = L.marker(
#                 [35.833049, 139.9550264],
#                 {}
#             ).addTo(map_3449f67134763ba5a9bbbc3662f741fb);
#
#
#             var icon_47505e16ec3b5818eed6e9a72a5f6a29 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ce0f3248ac6a3041f03b5fa897362d35.setIcon(icon_47505e16ec3b5818eed6e9a72a5f6a29);
#
#
#         var popup_95ba7db5bc6876cac6695ea307c8a93e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5cbf59328aebbb048d0aef735b5bdc88 = $(`&lt;div id=&quot;html_5cbf59328aebbb048d0aef735b5bdc88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:250px&quot;&gt;校舎名の「かえで」には「楓の果実が2つの種子が密着した姿で、それぞれから翼が伸びる翼果であることから、仲間同士で切磋琢磨し合い、成長を遂げていくことができる人材の育成を行う」という願いが込められています。&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_95ba7db5bc6876cac6695ea307c8a93e.setContent(html_5cbf59328aebbb048d0aef735b5bdc88);
#
#
#
#         marker_ce0f3248ac6a3041f03b5fa897362d35.bindPopup(popup_95ba7db5bc6876cac6695ea307c8a93e)
#         ;
#
#
#
#
#             marker_ce0f3248ac6a3041f03b5fa897362d35.bindTooltip(
#                 `&lt;div&gt;
#                      校舎「かえで」
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_88fd471c89e16e918a09299fdd4ed690 = L.marker(
#                 [35.83220147, 139.9559064],
#                 {}
#             ).addTo(map_3449f67134763ba5a9bbbc3662f741fb);
#
#
#             var icon_da36cb3154b846a7d9eef4ad4d635c81 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_88fd471c89e16e918a09299fdd4ed690.setIcon(icon_da36cb3154b846a7d9eef4ad4d635c81);
#
#
#         var popup_bf89ef61323666136fedda5ef57d7454 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c5e4c6dd76470614d2af0ad65b64553e = $(`&lt;div id=&quot;html_c5e4c6dd76470614d2af0ad65b64553e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:250px&quot;&gt;麗澤大学開学50周年記念事業の一環として2011年4月&quot;森と共生するキャンパス&quot;をコンセプトに建設された校舎「あすなろ」。このコンセプトが高く評価され、2012年度グッドデザイン賞を受賞しました。&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_bf89ef61323666136fedda5ef57d7454.setContent(html_c5e4c6dd76470614d2af0ad65b64553e);
#
#
#
#         marker_88fd471c89e16e918a09299fdd4ed690.bindPopup(popup_bf89ef61323666136fedda5ef57d7454)
#         ;
#
#
#
#
#             marker_88fd471c89e16e918a09299fdd4ed690.bindTooltip(
#                 `&lt;div&gt;
#                      校舎「あすなろ」
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_181646a9025b277c7f624f9e7fd97f7b = L.marker(
#                 [35.83286248, 139.9559251],
#                 {}
#             ).addTo(map_3449f67134763ba5a9bbbc3662f741fb);
#
#
#             var icon_90b39baf4de001ec121fe273f8495836 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_181646a9025b277c7f624f9e7fd97f7b.setIcon(icon_90b39baf4de001ec121fe273f8495836);
#
#
#         var popup_36b5d76efe3cd0164214c029fdafab73 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0de3401c3ac79a1ea3e8620e01b388ee = $(

# %% [markdown]
# `popup` の値に注目！そうなんです。日本語のテキストだと、popupが縦に表示されるため、これを回避するにはテキストの周りにHTMLで強引に `width` を設定します。
#
# <img src="https://raw.githubusercontent.com/yohman/23-1-Reitaku-GIS/main/Weeks/Week06/images/tate%20to%20yoko.png" width="400">

# %% [markdown]
# ### Basemap 色々
#
# デフォルトで使うベースマップは Open Street Map から。でも他にもオプションがいっぱいある。`folium` でマップを作るときに `tiles` と `attr` を指定することによってベースマップの変更が可能になる。
#
# 日本では国土交通省の国土地理院が様々なベースマップを提供している。以下のURLを `tiles` 変数に指定する。`attr` は `attribute` の略なので、必ず出所を指定する。この場合は `attr="国土地理院"`
#
# 2007年以降
# - https://cyberjapandata.gsi.go.jp/xyz/seamlessphoto/{z}/{x}/{y}.jpg
#
# 1987年～1990年
# - https://cyberjapandata.gsi.go.jp/xyz/gazo4/{z}/{x}/{y}.jpg
#
# 1984年～1986年
# - https://cyberjapandata.gsi.go.jp/xyz/gazo3/{z}/{x}/{y}.jpg
#
# 1979年～1983年
# - https://cyberjapandata.gsi.go.jp/xyz/gazo2/{z}/{x}/{y}.jpg
#
# 1974年～1978年
# - https://cyberjapandata.gsi.go.jp/xyz/gazo1/{z}/{x}/{y}.jpg
#
# 1961年～1969年
# - https://cyberjapandata.gsi.go.jp/xyz/ort_old10/{z}/{x}/{y}.png

# %%
# make the map
m = folium.Map(location=[center_lat,center_lon], 
               zoom_start=17,
               attr = '国土地理院')

# add basemaps
folium.TileLayer(name='2007年以降',tiles='https://cyberjapandata.gsi.go.jp/xyz/seamlessphoto/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1987年～1990年',tiles='https://cyberjapandata.gsi.go.jp/xyz/gazo4/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1984年～1986年',tiles='https://cyberjapandata.gsi.go.jp/xyz/gazo3/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1979年～1983年',tiles='https://cyberjapandata.gsi.go.jp/xyz/gazo2/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1974年～1978年',tiles='https://cyberjapandata.gsi.go.jp/xyz/gazo1/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1961年～1969年',tiles='https://cyberjapandata.gsi.go.jp/xyz/ort_old10/{z}/{x}/{y}.png',attr='国土地理院').add_to(m)

# basemapが選べるボタンをマップに足す
folium.LayerControl().add_to(m)

# add points
for index, row in df.iterrows():
    latlon = [row['latitude'],row['longitude']]
    folium.Marker(latlon, popup='<div style="width:350px">'+row['description']+'</div>', tooltip=row['name'],icon=folium.Icon(color=row['color'])).add_to(m)

# show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff9ef635f2c085ec86452467c99fba95 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff9ef635f2c085ec86452467c99fba95&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff9ef635f2c085ec86452467c99fba95 = L.map(
#                 &quot;map_ff9ef635f2c085ec86452467c99fba95&quot;,
#                 {
#                     center: [35.833078390000004, 139.95580603333335],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d8d73b4ec93aac604460ff4f1ed32f5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ff9ef635f2c085ec86452467c99fba95);
#
#
#             var tile_layer_5e4e024d00b81e4f21a4fb8d550c7f02 = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/seamlessphoto/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ff9ef635f2c085ec86452467c99fba95);
#
#
#             var tile_layer_11287842c5fa39a3f627f667286d3d75 = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/gazo4/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ff9ef635f2c085ec86452467c99fba95);
#
#
#             var tile_layer_d155e1f84e006c21e0eccecc6a7713d5 = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/gazo3/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ff9ef635f2c085ec86452467c99fba95);
#
#
#             var tile_layer_095eb78889bbb20161b106bd43d68b49 = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/gazo2/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ff9ef635f2c085ec86452467c99fba95);
#
#
#             var tile_layer_c9260f1b5769565301404b5a076492be = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/gazo1/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ff9ef635f2c085ec86452467c99fba95);
#
#
#             var tile_layer_c3b9d81400b4c9266154dfaaca62a6fc = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/ort_old10/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ff9ef635f2c085ec86452467c99fba95);
#
#
#             var layer_control_ed1c402d9d70d703c231f4cf0f980ca4 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_8d8d73b4ec93aac604460ff4f1ed32f5,
#                     &quot;2007\u5e74\u4ee5\u964d&quot; : tile_layer_5e4e024d00b81e4f21a4fb8d550c7f02,
#                     &quot;1987\u5e74\uff5e1990\u5e74&quot; : tile_layer_11287842c5fa39a3f627f667286d3d75,
#                     &quot;1984\u5e74\uff5e1986\u5e74&quot; : tile_layer_d155e1f84e006c21e0eccecc6a7713d5,
#                     &quot;1979\u5e74\uff5e1983\u5e74&quot; : tile_layer_095eb78889bbb20161b106bd43d68b49,
#                     &quot;1974\u5e74\uff5e1978\u5e74&quot; : tile_layer_c9260f1b5769565301404b5a076492be,
#                     &quot;1961

# %%
import folium
import random
from folium.plugins import BeautifyIcon

# Create a Tokyo map centered around its coordinates
tokyo_map = folium.Map(location=[35.682839, 139.759455], zoom_start=10)

# Generate 100 random markers in Tokyo with random colors
for _ in range(100):
    lat = 35.682839 + random.uniform(-0.1, 0.1)
    lon = 139.759455 + random.uniform(-0.1, 0.1)
    
    # Select a random color in CSS format (e.g., 'red', 'blue', etc.)
    random_color = random.choice(['red', 'blue', 'green', 'purple', 'orange', 'pink', 'brown', 'gray', 'black'])
    
    # Create a marker with the selected color for each random location
    html = f'<i class="fas fa-map-marker-alt" style="color: {random_color}; font-size: 24px;"></i>'
    marker = folium.Marker(location=[lat, lon], icon=BeautifyIcon(icon=html, inner_icon="pencil"))
    marker.add_to(tokyo_map)

    # Add a buffer (circle) around the marker with a random radius
    buffer_radius = random.randint(500, 2000)  # Radius in meters
    folium.Circle(location=[lat, lon], radius=buffer_radius, color=random_color, fill=True, fill_color=random_color, fill_opacity=0.2).add_to(tokyo_map)

# Save the map to an HTML file
tokyo_map.save('tokyo_markers_with_buffers.html')

# Display the map (optional, may not work in all environments)
tokyo_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa96d02d39e742aac07f254b1210b879 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa96d02d39e742aac07f254b1210b879&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa96d02d39e742aac07f254b1210b879 = L.map(
#                 &quot;map_aa96d02d39e742aac07f254b1210b879&quot;,
#                 {
#                     center: [35.682839, 139.759455],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e6b3e58f8d37a35e4d0f6b8eba17235 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aa96d02d39e742aac07f254b1210b879);
#
#
#             var marker_c5cda42a670a766afed79b65a06cd97b = L.marker(
#                 [35.733910846952206, 139.69211465399772],
#                 {}
#             ).addTo(map_aa96d02d39e742aac07f254b1210b879);
#
#
#             var beautify_icon_c00db8f4329c6ed7d1b8824332d50cc3 = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FFF&quot;, &quot;borderColor&quot;: &quot;#000&quot;, &quot;borderWidth&quot;: 3, &quot;icon&quot;: &quot;\u003ci class=\&quot;fas fa-map-marker-alt\&quot; style=\&quot;color: gray; font-size: 24px;\&quot;\u003e\u003c/i\u003e&quot;, &quot;innerIcon&quot;: &quot;pencil&quot;, &quot;innerIconStyle&quot;: &quot;&quot;, &quot;isAlphaNumericIcon&quot;: false, &quot;spin&quot;: false, &quot;textColor&quot;: &quot;#000&quot;}
#             )
#             marker_c5cda42a670a766afed79b65a06cd97b.setIcon(beautify_icon_c00db8f4329c6ed7d1b8824332d50cc3);
#
#
#             var circle_68291a51fb2291fb501427051c0940bd = L.circle(
#                 [35.733910846952206, 139.69211465399772],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1395, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aa96d02d39e742aac07f254b1210b879);
#
#
#             var marker_e795a8d6760da4066f7eeff30a3d8080 = L.marker(
#                 [35.73267511894291, 139.80906589540592],
#                 {}
#             ).addTo(map_aa96d02d39e742aac07f254b1210b879);
#
#
#             var beautify_icon_8d698d1696897de55bde2d4697ad05ce = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FFF&quot;, &quot;borderColor&quot;: &quot;#000&quot;, &quot;borderWidth&quot;: 3, &quot;icon&quot;: &quot;\u003ci class=\&quot;fas fa-map-marker-alt\&quot; style=\&quot;color: blue; font-size: 24px;\&quot;\u003e\u003c/i\u003e&quot;, &quot;innerIcon&quot;: &quot;pencil&quot;, &quot;innerIconStyle&quot;: &quot;&quot;, &quot;isAlphaNumericIcon&quot;: false, &quot;spin&quot;: false, &quot;textColor&quot;: &quot;#000&quot;}
#             )
#             marker_e795a8d6760da4066f7eeff30a3d8080.setIcon(beautify_icon_8d698d1696897de55bde2d4697ad05ce);
#
#
#             var circle_b8e6772eaa40f5b8d204e59b0a1d05d8 = L.circle(
#                 [35.73267511894291, 139.80906589540592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1216, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aa96d02d39e742aac07f254b1210b879);
#
#
#             var marker_5273976ce95e7d2fdc6fdb1f5922d3b6 = L.marker(
#                 [35.75922734059069, 139.7439876118582],
#                 {}
#             ).addTo(map_aa96d02d39e742aac07f254b1210b879);
#
#
#             var beautify_icon_fb8d4fc96d1b5762a6487dcd979e0a3d = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FFF&quot;, &quot;borderColor&quot;: &quot;#000&quot;, &quot;borderWidth&quot;: 3, &quot;icon&quot;: &quot;\u003ci class=\&quot;fas fa-map-marker-alt\&quot; style=\&quot;color: orange; font-size: 24px;\&quot;\u003e\u003c/i\u003e&quot;, &quot;innerIco

# %%
# save the map as an html file
m.save('map.html')

# %% [markdown]
# このように同じ「場所」を違う視点から観察することができる。これを見て、何を感じますか？

# %% [markdown]
# # Extra topic: Mapping Earthquakes
#
# 世界の地震のデータをリアルタイムで提供しているのは United States Geological Survey (USGS)。このデータをcsv fileとしてダウンロードできるが、直接アクセスすることも可能である。この場合、 `csv` ではなく `geojson` というファイルフォーマットを使う。`geojson` はこれからも使うので、とりあえず、ここで紹介！
#
# `geojson` を扱うには新しいライブラリー【geopandas】を使う必要がある。
#
# [USGSの地震マップ](https://earthquake.usgs.gov/earthquakes/map/?extent=-82.76537,-120.23438&extent=84.9593,298.47656)

# %%
import geopandas as gpd

# %% [markdown]
# `geopandas` を使ってUSGSからのリアルタイムデータを読み込む。`gdf` とは `geodataframe` の略である。

# %%
gdf = gpd.read_file('https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_day.geojson')

# %%
# use head to output first 5 rows
gdf.head()
# Out:
#              id   mag                               place           time  \
# 0    us7000l80y  4.90                       Kuril Islands  1698826129166
# 1  ak023e0jc723  3.20   34 km SSW of Glacier View, Alaska  1698824624611
# 2    us7000l80q  5.20  94 km ESE of Lata, Solomon Islands  1698821503829
# 3    us7000l80p  4.60  94 km ESE of Lata, Solomon Islands  1698820178508
# 4    nc73954455  2.45           19 km NW of Parkfield, CA  1698813050560
#
#          updated  tz                                                url  \
# 0  1698827177040 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  1698827428658 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  1698822700040 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  1698821922040 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  1698818773298 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                               detail  felt  cdi  ...  sources  \
# 0  https://earthquake.usgs.gov/earthquakes/feed/v...   NaN  NaN  ...     ,us,
# 1  https://earthquake.usgs.gov/earthquakes/feed/v...   6.0  2.7  ...     ,ak,
# 2  https://earthquake.usgs.gov/earthquakes/feed/v...   NaN  NaN  ...     ,us,
# 3  https://earthquake.usgs.gov/earthquakes/feed/v...   NaN  NaN  ...     ,us,
# 4  https://earthquake.usgs.gov/earthquakes/feed/v...   NaN  NaN  ...     ,nc,
#
#                                                types   nst   dmin   rms  \
# 0                                ,origin,phase-data,  54.0  4.613  1.12
# 1                           ,dyfi,origin,phase-data,   NaN    NaN  0.75
# 2                                ,origin,phase-data,  43.0  9.806  0.78
# 3                                ,origin,phase-data,  34.0  9.808  0.51
# 4  ,focal-mechanism,nearby-cities,origin,phase-da...  42.0    NaN  0.06
#
#      gap magType        type                                       title  \
# 0  170.0      mb  earthquake                       M 4.9 - Kuril Islands
# 1    NaN      ml  earthquake   M 3.2 - 34 km SSW of Glacier View, Alaska
# 2  122.0     mww  earthquake  M 5.2 - 94 km ESE of Lata, Solomon Islands
# 3  130.0      mb  earthquake  M 4.6 - 94 km ESE of Lata, Solomon Islands
# 4   43.0      md  earthquake           M 2.5 - 19 km NW of Parkfield, CA
#
#                                  geometry
# 0   POINT Z (149.00380 44.35770 56.44100)
# 1  POINT Z (-147.82590 61.51110 13.60000)
# 2  POINT Z (166.62740 -10.95200 66.40500)
# 3  POINT Z (166.62860 -10.94990 73.86100)
# 4   POINT Z (-120.58033 36.02083 4.25000)
#
# [5 rows x 28 columns]

# %%
# make the map
eqmap = folium.Map(location=[0,0], 
               zoom_start=1,
               tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
               attr = 'ESRI')

folium.GeoJson(gdf,
               tooltip=folium.GeoJsonTooltip(fields=['title'])).add_to(eqmap)
eqmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae018a5906c09135cb0d9b31d2445f0a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae018a5906c09135cb0d9b31d2445f0a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae018a5906c09135cb0d9b31d2445f0a = L.map(
#                 &quot;map_ae018a5906c09135cb0d9b31d2445f0a&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f45c91d69473007e5ad60765f08c60dd = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;ESRI&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ae018a5906c09135cb0d9b31d2445f0a);
#
#
#
#         function geo_json_54bab59c04f409177da766a98f480ee7_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_54bab59c04f409177da766a98f480ee7 = L.geoJson(null, {
#                 onEachFeature: geo_json_54bab59c04f409177da766a98f480ee7_onEachFeature,
#
#         });
#
#         function geo_json_54bab59c04f409177da766a98f480ee7_add (data) {
#             geo_json_54bab59c04f409177da766a98f480ee7
#                 .addData(data)
#                 .addTo(map_ae018a5906c09135cb0d9b31d2445f0a);
#         }
#             geo_json_54bab59c04f409177da766a98f480ee7_add({&quot;bbox&quot;: [-179.0072, -28.7471, 178.9955, 67.2794], &quot;features&quot;: [{&quot;bbox&quot;: [149.0038, 44.3577, 149.0038, 44.3577], &quot;geometry&quot;: {&quot;coordinates&quot;: [149.0038, 44.3577, 56.441], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;alert&quot;: null, &quot;cdi&quot;: null, &quot;code&quot;: &quot;7000l80y&quot;, &quot;detail&quot;: &quot;https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000l80y.geojson&quot;, &quot;dmin&quot;: 4.613, &quot;felt&quot;: null, &quot;gap&quot;: 170.0, &quot;id&quot;: &quot;us7000l80y&quot;, &quot;ids&quot;: &quot;,us7000l80y,&quot;, &quot;mag&quot;: 4.9, &quot;magType&quot;: &quot;mb&quot;, &quot;mmi&quot;: null, &quot;net&quot;: &quot;us&quot;, &quot;nst&quot;: 54.0, &quot;place&quot;: &quot;Kuril Islands&quot;, &quot;rms&quot;: 1.12, &quot;sig&quot;: 369, &quot;sources&quot;: &quot;,us,&quot;, &quot;status&quot;: &quot;reviewed&quot;, &quot;time&quot;: 1698826129166, &quot;title&quot;: &quot;M 4.9 - Kuril Islands&quot;, &quot;tsunami&quot;: 0, &quot;type&quot;: &quot;earthquake&quot;, &quot;types&quot;: &quot;,origin,phase-data,&quot;, &quot;tz&quot;: null, &quot;updated&quot;: 1698827177040, &quot;url&quot;: &quot;https://earthquake.usgs.gov/earthquakes/eventpage/us7000l80y&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-147.8259, 61.5111, -147.8259, 61.5111], &quot;geometry&quot;: {&quot;coordinates&quot;: [-147.8259, 61.5111, 13.6], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;alert&quot;: null, &quot;cdi&quot;: 2.7, &quot;code&quot;: &quot;023e0jc723&quot;, &quot;detail&quot;: &quot;https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak023e0jc723.geojson&quot;, &quot;dmin&quot;: null, &quot;felt&quot;: 6.0, &quot;gap&quot;: null, &quot;id&quot;: &quot;ak023e0jc723&quot;, &quot;ids&quot;: &quot;,ak023e0jc723,&quot;, &quot;mag&quot;: 3.2, &quot;magType&quot;: &quot;ml&quot;, &quot;mmi&quot;: null, &quot;net&quot;: &quot;ak&quot;, &quot;nst&quot;: null, &quot;place&quot;: &quot;34 km SSW of Glacier View, Alaska&quot;, &quot;rms&quot;: 0.75, &quot;sig&quot;: 159, &quot;sources&quot;: &quot;,ak,&quot;, &quot;status&quot;: &quot;automatic&quot;, &quot;time&quot;: 1698824624611, &quot;title&quot;: &quot;M 3.2 - 34 km SSW of Glacier View, Alaska&quot;, &quot;tsunami&quot;: 0, &quot;type&quot;: &quot;earthquake&quot;, &quot;types&quot;: &quot;,dyfi,origin,phase-data,&quot;, &quot;tz&quot;: null, &quot;updated&quot;: 1698827428658, &quot;url&quot;: &quot;https://earthquake.usgs.gov/earthquakes/eventpage/ak023e0jc723&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [166.6274, -10.952, 166.6274, -10.952], &quot;geometry&quot;: {&quot;coordinates&quot;: [166.6274, -10.952, 66.405], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;alert&quot;: null, &quot;cdi&quot;: null, &quot;code&quot;: &quot;7000l80q&quot;, &quot;detail&quot;: &quot;https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000l80q.geojson&quot;, &quot;dmi

# %% [markdown]
# ここで考えほしいのは、csv をダウンロードした場合と、このように直接出所にリンクしてデータを入手する「違い」とは何か？
