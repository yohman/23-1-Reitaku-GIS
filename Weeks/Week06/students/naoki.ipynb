# %% [markdown]
# # My map
#
# I'll post some gym recommendations near here!
# The green marker is Reitaku.
#
# The red marker is the gym I use most often.
#
# The purple marker is the closest gym to the University.
# This gym is called Anytime and is located all over the world.
#
# The orange marker is the gym I recommend the most.
# He owner of this gym is an active physique athlete and it is a cheap, high quality gym.

# %%
import folium

reitaku=(35.8330, 139.9550)
gym=folium.Map(location=reitaku,zoom_start=12)

folium.Marker(location=reitaku,popup='My University',tooltip='Reitaku',icon=folium.Icon(color="green")).add_to(gym)

mygym=35.8793487859615, 139.96800873757294
folium.Marker(location=mygym,popup='I always use the gym.',tooltip='My gym',icon=folium.Icon(color="red")).add_to(gym)

closegym=35.848318520795374, 139.95377511849304
folium.Marker(location=closegym,popup='These gyms are located all over the world.',tooltip='Gym close to the university',icon=folium.Icon(color="purple")).add_to(gym)

bestgym=35.82528901933755, 139.91992856931068
folium.Marker(location=bestgym,popup='This is the best gym, cheap and good quality.',tooltip='My recommendation for gyms.',icon=folium.Icon(color="orange")).add_to(gym)

gym
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86ae1f6fd32c87a912208a92a89da9a8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86ae1f6fd32c87a912208a92a89da9a8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86ae1f6fd32c87a912208a92a89da9a8 = L.map(
#                 &quot;map_86ae1f6fd32c87a912208a92a89da9a8&quot;,
#                 {
#                     center: [35.833, 139.955],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1a8a0eae7c0744b2d320827d64194fe3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_86ae1f6fd32c87a912208a92a89da9a8);
#
#
#             var marker_bdab7f44e53a354eea6a8c2881e9c7d7 = L.marker(
#                 [35.833, 139.955],
#                 {}
#             ).addTo(map_86ae1f6fd32c87a912208a92a89da9a8);
#
#
#             var icon_f571b9ebcee915b6c700a3ef383f6802 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bdab7f44e53a354eea6a8c2881e9c7d7.setIcon(icon_f571b9ebcee915b6c700a3ef383f6802);
#
#
#         var popup_83f1b6c4227a9ce44d88aaf841fb5052 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ff0432409c5665540e3f0aa6bd8272a0 = $(`&lt;div id=&quot;html_ff0432409c5665540e3f0aa6bd8272a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;My University&lt;/div&gt;`)[0];
#                 popup_83f1b6c4227a9ce44d88aaf841fb5052.setContent(html_ff0432409c5665540e3f0aa6bd8272a0);
#
#
#
#         marker_bdab7f44e53a354eea6a8c2881e9c7d7.bindPopup(popup_83f1b6c4227a9ce44d88aaf841fb5052)
#         ;
#
#
#
#
#             marker_bdab7f44e53a354eea6a8c2881e9c7d7.bindTooltip(
#                 `&lt;div&gt;
#                      Reitaku
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c8461c887d2aa6b1a612c09d5db99f14 = L.marker(
#                 [35.8793487859615, 139.96800873757294],
#                 {}
#             ).addTo(map_86ae1f6fd32c87a912208a92a89da9a8);
#
#
#             var icon_8879eab79039c8c4f7a105fb16b9237f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c8461c887d2aa6b1a612c09d5db99f14.setIcon(icon_8879eab79039c8c4f7a105fb16b9237f);
#
#
#         var popup_b2a57bc3876ee1bed5bea2ac40b6ce26 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0384a8ed382c842371fc4cea37a7000c = $(`&lt;div id=&quot;html_0384a8ed382c842371fc4cea37a7000c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I always use the gym.&lt;/div&gt;`)[0];
#                 popup_b2a57bc3876ee1bed5bea2ac40b6ce26.setContent(html_0384a8ed382c842371fc4cea37a7000c);
#
#
#
#         marker_c8461c887d2aa6b1a612c09d5db99f14.bindPopup(popup_b2a57bc3876ee1bed5bea2ac40b6ce26)
#         ;
#
#
#
#
#             marker_c8461c887d2aa6b1a612c09d5db99f14.bindTooltip(
#                 `&lt;div&gt;
#                      My gym
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2edac7dba83290e339b85faf1cdd9cfe = L.marker(
#                 [35.848318520795374, 139.95377511849304],
#                 {}
#             ).addTo(map_86ae1f6fd32c87a912208a92a89da9a8);
#
#
#             var icon_40942f988208a092ba2c62bc6d73934b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2edac7dba83290e339b85faf1cdd9cfe.setIcon(icon_40942f988208a092ba2c62bc6d73934b);
#
#
#         var popup_557dd140048714021b4a77103c939bc4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cdc841036710618d08305520759b3585 = $(`&lt;div id=&quot;html_cdc841036710618d08305520759b3585&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;These gyms are located all over the world.&lt;/div&gt;`)[0];
#                 popup_557dd140048714021b4a77103c939bc4.setContent(html_cdc841036710618d08305520759b3585);
